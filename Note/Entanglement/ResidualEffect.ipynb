# %% [markdown]
# # Residual effect on the robustness of multiqubit entanglement

# %% [markdown]
# We investigate the relation between the entanglement and the robustness of a multipartite system to a depolarization noise.
#
# For a two-qubit system in an arbitrary pure entangled state, its robustness increases synchronously with its entanglement.
#
# For a three-qubit system, this phenomenon, however, disappears and the robustness of GHZ-like states, which have only three-tangle (the entanglement shared by all the three qubits) without concurrence, is the upper boundary of symmetrical three-qubit pure states.
#
# It is interesting to point out that there is a residual effect on the robustness of a three-qubit system in an arbitrary superposition of a GHZ state and a W state.

# %% [markdown]
# ## local decoherence
# $$
# \varepsilon\left(\rho_{i}(0)\right)=\sum_{j=1}^{3} E_{j i}(t) \rho_{i}(0) E_{j i}^{\dagger}(t)
# $$

# %% [markdown]
# ## Two-qubit quantum system
# $$
# R=1-\frac{1}{\sqrt{1+2 N}}
# $$
# R stands for robustness which is the maximum noise the system can take before it's separable.

# %% [markdown]
# ## Three-qubit symmetric states
# ![Alt text](Figure\1.png)
# 1. $|W-like\rangle=\sqrt{b}|000\rangle+\sqrt{\frac{1-b}{3}}(|001\rangle+|010\rangle+|100\rangle)= |W000\rangle$
# 2. Random states are generated by four symmetric states based on haar measure
# 3. For each class of entangled states, on the one hand, the more the entanglement, the more its robustness.
# 4. Generally speaking, for three-qubit symmetric states, the more the entanglement, the more the robustness of a symmetrical three-qubit pure state.
# 5. Since GHZ-like only have three tangle, and it's of the most robustness of a given $N_0$, three-tangle is the highest quality (the most robust) entanglement against the depolarization noise.

# %% [markdown]
# ## Residue Effect
# In a three-qubit system, the negativity only measures a bipartite entanglement, while the three-tangle quantifies genuine multipartite correlations.
#
# To explore the effects of different entanglements, they find following states. For its negativity dose not depend on $\phi$, given a, negativity is fixed.
# $$
# \begin{aligned}
# |Z(a, \varphi)\rangle&=\sqrt{a}|\mathrm{GHZ}\rangle-e^{i \varphi} \sqrt{1-a}|W\rangle\\
# N[|Z(a, \varphi)\rangle]&=\frac{\sqrt{5 a^{2}-4 a+8}}{3}\\
# \tau[|Z(a, \varphi)\rangle] &=\left|a^{2}-\frac{8 \sqrt{6}}{9} \sqrt{a(1-a)^{3}} e^{3 i \varphi}\right|
# \end{aligned}
# $$
# ![Alt text](Figure\2.png)
#
# In figure above, $\varphi = \gamma \frac{2\pi}{3}$
#
# ![Alt text](Figure\3.png)
